# %%
print('ello world')
# Out:
# ello world

# %%
a=2
b=3
print(a+b)
# Out:
# 5

# %%
print(9)
# Out:
# 9

# %%
k=5
print(k)
# Out:
# 5

# %%
k='g-o-0'
print(k)
# Out:
# g-o-0

# %%
print('k=',k)
# Out:
# k= g-o-0
